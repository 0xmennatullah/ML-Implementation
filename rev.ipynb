# %% [markdown]
# # general useful notebooks:
# 1. [overall ML](https://www.kaggle.com/code/kanncaa1/machine-learning-tutorial-for-beginners)
# 2. [most classification models](https://www.kaggle.com/code/fareselmenshawii/breast-cancer-various-models)
# 3. [from scratch series](https://www.kaggle.com/code/fareselmenshawii/knn-from-scratch?scriptVersionId=130404721&cellId=46)
# 4. [EDA | KNN + NB + Logistic](https://www.kaggle.com/code/arezalo/drug-classification-eda-knn-nb-logistic)
